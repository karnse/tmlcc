# %%
import json
t = open('func_gro.json')
func_group=json.load(t)
t = open('map_topology.json')
topo = json.load(t)

# %%
with open('test.csv') as fp:
    lines = fp.readlines()

# %%
with open('test_edit.csv') as fp2:
    lines2=fp2.readlines()

# %%
data=[]
for line in lines:
    data.append(line.split(','))

# %%
datae=[]
for line in lines2:
    datae.append(line.split(','))

# %%
data[1]
# Out:
# ['mof_unit_68614',
#  '1208.301332',
#  '797.70936',
#  '586.54',
#  '0.11392',
#  '0.1039',
#  'OEt',
#  '2',
#  '5',
#  '26',
#  'pcu',
#  '36.63979083',
#  '7.00564\n']

# %%
cnt=0
dats=[]
for i in range(14):
    dats.append([])
for i in data[1:]:
    cnt+=1
    dats[-1].append(i[0])
    dats[0].append(float(i[1]))
    dats[1].append(float(i[2]))
    dats[2].append(float(i[3]))
    dats[3].append(float(i[4]))
    dats[4].append(float(i[5]))
    func = i[6].split('-')
    if func[0]=='':
        dats[5].append(-1)
        dats[6].append(-1)
    elif len(func)==1:
        dats[5].append(func_group[func[0]])
        dats[6].append(-1)
    elif len(func)==2:
        dats[5].append(func_group[func[0]])
        dats[6].append(func_group[func[1]])
    dats[7].append(int(i[7]))
    dats[8].append(int(i[8]))
    dats[9].append(int(i[9]))
    dats[10].append(topo[i[10]])
    dats[11].append(float(i[11]))
    dats[12].append(float(i[12]))
cnt
# Out:
# 17000

# %%
datae[1][0]=datae[1][0][0:]
datae
# Out:
# [['\ufeffMOFname',
#   'metal_linker',
#   'organic_linker1',
#   'organic_linker2',
#   'topology',
#   'flag\n'],
#  ['mof_unit_68751', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_68901', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_69022', '9', '15', '2', 'sra', 'test\n'],
#  ['mof_unit_69223', '9', '4', '15', 'sra', 'test\n'],
#  ['mof_unit_69325', '9', '1', '15', 'sra', 'test\n'],
#  ['mof_unit_69430', '9', '1', '15', 'sra', 'test\n'],
#  ['mof_unit_69625', '9', '4', '15', 'sra', 'test\n'],
#  ['mof_unit_69710', '9', '4', '15', 'sra', 'test\n'],
#  ['mof_unit_69746', '9', '15', '2', 'sra', 'test\n'],
#  ['mof_unit_69935', '9', '12', '15', 'sra', 'test\n'],
#  ['mof_unit_70316', '9', '4', '15', 'sra', 'test\n'],
#  ['mof_unit_70469', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_70495', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_70512', '9', '12', '15', 'sra', 'test\n'],
#  ['mof_unit_70628', '9', '15', '23', 'sra', 'test\n'],
#  ['mof_unit_70660', '9', '15', '2', 'sra', 'test\n'],
#  ['mof_unit_70749', '9', '15', '25', 'sra', 'test\n'],
#  ['mof_unit_70784', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_71002', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_71080', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_71341', '9', '15', '20', 'sra', 'test\n'],
#  ['mof_unit_71570', '9', '12', '15', 'sra', 'test\n'],
#  ['mof_unit_71573', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_71657', '9', '15', '19', 'sra', 'test\n'],
#  ['mof_unit_71909', '9', '15', '2', 'sra', 'test\n'],
#  ['mof_unit_72108', '9', '15', '25', 'sra', 'test\n'],
#  ['mof_unit_72168', '9', '15', '2', 'sra', 'test\n'],
#  ['mof_unit_72186', '9', '15', '25', 'sra', 'test\n'],
#  ['mof_unit_72222', '9', '15', '2', 'sra', 'test\n'],
#  ['mof_unit_72700', '9', '4', '15', 'sra', 'test\n'],
#  ['mof_unit_72737', '9', '15', '23', 'sra', 'test\n'],
#  ['mof_unit_72936', '9', '12', '15', 'sra', 'test\n'],
#  ['mof_unit_72994', '9', '4', '15', 'sra', 'test\n'],
#  ['mof_unit_73120', '9', '15', '23', 'sra', 'test\n'],
#  ['mof_unit_73218', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_73359', '9', '15', '2', 'sra', 'test\n'],
#  ['mof_unit_73373', '9', '15', '23', 'sra', 'test\n'],
#  ['mof_unit_73379', '9', '15', '20', 'sra', 'test\n'],
#  ['mof_unit_73456', '9', '4', '15', 'sra', 'test\n'],
#  ['mof_unit_73495', '9', '12', '15', 'sra', 'test\n'],
#  ['mof_unit_73561', '9', '15', '20', 'sra', 'test\n'],
#  ['mof_unit_73696', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_73707', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_73802', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_73850', '9', '15', '23', 'sra', 'test\n'],
#  ['mof_unit_73866', '9', '15', '2', 'sra', 'test\n'],
#  ['mof_unit_74317', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_74399', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_74411', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_74455', '9', '15', '19', 'sra', 'test\n'],
#  ['mof_unit_74476', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_74490', '9', '1', '15', 'sra', 'test\n'],
#  ['mof_unit_74611', '9', '15', '2', 'sra', 'test\n'],
#  ['mof_unit_74617', '9', '15', '25', 'sra', 'test\n'],
#  ['mof_unit_74622', '9', '1', '15', 'sra', 'test\n'],
#  ['mof_unit_74707', '9', '4', '15', 'sra', 'test\n'],
#  ['mof_unit_74789', '9', '15', '20', 'sra', 'test\n'],
#  ['mof_unit_74873', '9', '15', '23', 'sra', 'test\n'],
#  ['mof_unit_74934', '9', '15', '20', 'sra', 'test\n'],
#  ['mof_unit_74978', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_75153', '9', '1', '15', 'sra', 'test\n'],
#  ['mof_unit_75164', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_75199', '9', '1', '15', 'sra', 'test\n'],
#  ['mof_unit_75296', '9', '15', '20', 'sra', 'test\n'],
#  ['mof_unit_75402', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_75471', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_75493', '9', '4', '15', 'sra', 'test\n'],
#  ['mof_unit_75530', '9', '15', '2', 'sra', 'test\n'],
#  ['mof_unit_75547', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_75560', '9', '15', '2', 'sra', 'test\n'],
#  ['mof_unit_76289', '9', '15', '25', 'sra', 'test\n'],
#  ['mof_unit_76528', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_76711', '9', '1', '15', 'sra', 'test\n'],
#  ['mof_unit_76737', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_76890', '9', '15', '25', 'sra', 'test\n'],
#  ['mof_unit_77031', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_77166', '9', '12', '15', 'sra', 'test\n'],
#  ['mof_unit_77179', '9', '15', '23', 'sra', 'test\n'],
#  ['mof_unit_77584', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_77653', '9', '15', '23', 'sra', 'test\n'],
#  ['mof_unit_77666', '9', '15', '20', 'sra', 'test\n'],
#  ['mof_unit_77841', '9', '12', '15', 'sra', 'test\n'],
#  ['mof_unit_77855', '9', '15', '2', 'sra', 'test\n'],
#  ['mof_unit_77950', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_78037', '9', '1', '15', 'sra', 'test\n'],
#  ['mof_unit_78216', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_78239', '9', '15', '20', 'sra', 'test\n'],
#  ['mof_unit_78570', '9', '12', '15', 'sra', 'test\n'],
#  ['mof_unit_78647', '9', '4', '15', 'sra', 'test\n'],
#  ['mof_unit_78774', '9', '12', '15', 'sra', 'test\n'],
#  ['mof_unit_78802', '9', '15', '20', 'sra', 'test\n'],
#  ['mof_unit_79010', '9', '15', '25', 'sra', 'test\n'],
#  ['mof_unit_79020', '9', '15', '19', 'sra', 'test\n'],
#  ['mof_unit_79030', '9', '15', '20', 'sra', 'test\n'],
#  ['mof_unit_79155', '9', '1', '15', 'sra', 'test\n'],
#  ['mof_unit_79363', '9', '15', '19', 'sra', 'test\n'],
#  ['mof_unit_79440', '9', '1', '15', 'sra', 'test\n'],
#  ['mof_unit_79648', '9', '15', '2', 'sra', 'test\n'],
#  ['mof_unit_79818', '9', '15', '20', 'sra', 'test\n'],
#  ['mof_unit_80215', '9', '1', '15', 'sra', 'test\n'],
#  ['mof_unit_80221', '9', '15', '23', 'sra', 'test\n'],
#  ['mof_unit_80230', '9', '15', '20', 'sra', 'test\n'],
#  ['mof_unit_80298', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_80398', '9', '12', '15', 'sra', 'test\n'],
#  ['mof_unit_80401', '9', '15', '2', 'sra', 'test\n'],
#  ['mof_unit_80539', '9', '1', '15', 'sra', 'test\n'],
#  ['mof_unit_80546', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_80686', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_80885', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_80937', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_80956', '9', '12', '15', 'sra', 'test\n'],
#  ['mof_unit_81097', '9', '15', '25', 'sra', 'test\n'],
#  ['mof_unit_81424', '9', '4', '15', 'sra', 'test\n'],
#  ['mof_unit_81454', '9', '15', '2', 'sra', 'test\n'],
#  ['mof_unit_81513', '9', '15', '19', 'sra', 'test\n'],
#  ['mof_unit_81766', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_81799', '9', '15', '2', 'sra', 'test\n'],
#  ['mof_unit_82055', '9', '1', '15', 'sra', 'test\n'],
#  ['mof_unit_82134', '9', '15', '2', 'sra', 'test\n'],
#  ['mof_unit_82169', '9', '1', '15', 'sra', 'test\n'],
#  ['mof_unit_82271', '9', '15', '23', 'sra', 'test\n'],
#  ['mof_unit_82329', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_82348', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_82385', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_82425', '9', '15', '25', 'sra', 'test\n'],
#  ['mof_unit_82650', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_82679', '9', '11', '15', 'sra', 'test\n'],
#  ['mof_unit_82843', '9', '4', '15', 'sra', 'test\n'],
#  ['mof_unit_82874', '9', '15', '25', 'sra', 'test\n'],
#  ['mof_unit_82922', '9', '13', '15', 'sra', 'test\n']]

# %%
cnt2=0
for i in datae[1:]:
    print(i[0])
    for j in range(len(dats[0])):
        if dats[-1][j]==i[0]:
            cnt2+=1
            print(cnt2,i[0])
            dats[7][j]=int(i[1])
            dats[8][j]=int(i[2])
            dats[9][j]=int(i[3])
            dats[10][j]=topo[i[4]]
# Out:
# mof_unit_68751
# 1 mof_unit_68751
# mof_unit_68901
# 2 mof_unit_68901
# mof_unit_69022
# 3 mof_unit_69022
# mof_unit_69223
# 4 mof_unit_69223
# mof_unit_69325
# 5 mof_unit_69325
# mof_unit_69430
# 6 mof_unit_69430
# mof_unit_69625
# 7 mof_unit_69625
# mof_unit_69710
# 8 mof_unit_69710
# mof_unit_69746
# 9 mof_unit_69746
# mof_unit_69935
# 10 mof_unit_69935
# mof_unit_70316
# 11 mof_unit_70316
# mof_unit_70469
# 12 mof_unit_70469
# mof_unit_70495
# 13 mof_unit_70495
# mof_unit_70512
# 14 mof_unit_70512
# mof_unit_70628
# 15 mof_unit_70628
# mof_unit_70660
# 16 mof_unit_70660
# mof_unit_70749
# 17 mof_unit_70749
# mof_unit_70784
# 18 mof_unit_70784
# mof_unit_71002
# 19 mof_unit_71002
# mof_unit_71080
# 20 mof_unit_71080
# mof_unit_71341
# 21 mof_unit_71341
# mof_unit_71570
# 22 mof_unit_71570
# mof_unit_71573
# 23 mof_unit_71573
# mof_unit_71657
# 24 mof_unit_71657
# mof_unit_71909
# 25 mof_unit_71909
# mof_unit_72108
# 26 mof_unit_72108
# mof_unit_72168
# 27 mof_unit_72168
# mof_unit_72186
# 28 mof_unit_72186
# mof_unit_72222
# 29 mof_unit_72222
# mof_unit_72700
# 30 mof_unit_72700
# mof_unit_72737
# 31 mof_unit_72737
# mof_unit_72936
# 32 mof_unit_72936
# mof_unit_72994
# 33 mof_unit_72994
# mof_unit_73120
# 34 mof_unit_73120
# mof_unit_73218
# 35 mof_unit_73218
# mof_unit_73359
# 36 mof_unit_73359
# mof_unit_73373
# 37 mof_unit_73373
# mof_unit_73379
# 38 mof_unit_73379
# mof_unit_73456
# 39 mof_unit_73456
# mof_unit_73495
# 40 mof_unit_73495
# mof_unit_73561
# 41 mof_unit_73561
# mof_unit_73696
# 42 mof_unit_73696
# mof_unit_73707
# 43 mof_unit_73707
# mof_unit_73802
# 44 mof_unit_73802
# mof_unit_73850
# 45 mof_unit_73850
# mof_unit_73866
# 46 mof_unit_73866
# mof_unit_74317
# 47 mof_unit_74317
# mof_unit_74399
# 48 mof_unit_74399
# mof_unit_74411
# 49 mof_unit_74411
# mof_unit_74455
# 50 mof_unit_74455
# mof_unit_74476
# 51 mof_unit_74476
# mof_unit_74490
# 52 mof_unit_74490
# mof_unit_74611
# 53 mof_unit_74611
# mof_unit_74617
# 54 mof_unit_74617
# mof_unit_74622
# 55 mof_unit_74622
# mof_unit_74707
# 56 mof_unit_74707
# mof_unit_74789
# 57 mof_unit_74789
# mof_unit_74873
# 58 mof_unit_74873
# mof_unit_74934
# 59 mof_unit_74934
# mof_unit_74978
# 60 mof_unit_74978
# mof_unit_75153
# 61 mof_unit_75153
# mof_unit_75164
# 62 mof_unit_75164
# mof_unit_75199
# 63 mof_unit_75199
# mof_unit_75296
# 64 mof_unit_75296
# mof_unit_75402
# 65 mof_unit_75402
# mof_unit_75471
# 66 mof_unit_75471
# mof_unit_75493
# 67 mof_unit_75493
# mof_unit_75530
# 68 mof_unit_75530
# mof_unit_75547
# 69 mof_unit_75547
# mof_unit_75560
# 70 mof_unit_75560
# mof_unit_76289
# 71 mof_unit_76289
# mof_unit_76528
# 72 mof_unit_76528
# mof_unit_76711
# 73 mof_unit_76711
# mof_unit_76737
# 74 mof_unit_76737
# mof_unit_76890
# 75 mof_unit_76890
# mof_unit_77031
# 76 mof_unit_77031
# mof_unit_77166
# 77 mof_unit_77166
# mof_unit_77179
# 78 mof_unit_77179
# mof_unit_77584
# 79 mof_unit_77584
# mof_unit_77653
# 80 mof_unit_77653
# mof_unit_77666
# 81 mof_unit_77666
# mof_unit_77841
# 82 mof_unit_77841
# mof_unit_77855
# 83 mof_unit_77855
# mof_unit_77950
# 84 mof_unit_77950
# mof_unit_78037
# 85 mof_unit_78037
# mof_unit_78216
# 86 mof_unit_78216
# mof_unit_78239
# 87 mof_unit_78239
# mof_unit_78570
# 88 mof_unit_78570
# mof_unit_78647
# 89 mof_unit_78647
# mof_unit_78774
# 90 mof_unit_78774
# mof_unit_78802
# 91 mof_unit_78802
# mof_unit_79010
# 92 mof_unit_79010
# mof_unit_79020
# 93 mof_unit_79020
# mof_unit_79030
# 94 mof_unit_79030
# mof_unit_79155
# 95 mof_unit_79155
# mof_unit_79363
# 96 mof_unit_79363
# mof_unit_79440
# 97 mof_unit_79440
# mof_unit_79648
# 98 mof_unit_79648
# mof_unit_79818
# 99 mof_unit_79818
# mof_unit_80215
# 100 mof_unit_80215
# mof_unit_80221
# 101 mof_unit_80221
# mof_unit_80230
# 102 mof_unit_80230
# mof_unit_80298
# 103 mof_unit_80298
# mof_unit_80398
# 104 mof_unit_80398
# mof_unit_80401
# 105 mof_unit_80401
# mof_unit_80539
# 106 mof_unit_80539
# mof_unit_80546
# 107 mof_unit_80546
# mof_unit_80686
# 108 mof_unit_80686
# mof_unit_80885
# 109 mof_unit_80885
# mof_unit_80937
# 110 mof_unit_80937
# mof_unit_80956
# 111 mof_unit_80956
# mof_unit_81097
# 112 mof_unit_81097
# mof_unit_81424
# 113 mof_unit_81424
# mof_unit_81454
# 114 mof_unit_81454
# mof_unit_81513
# 115 mof_unit_81513
# mof_unit_81766
# 116 mof_unit_81766
# mof_unit_81799
# 117 mof_unit_81799
# mof_unit_82055
# 118 mof_unit_82055
# mof_unit_82134
# 119 mof_unit_82134
# mof_unit_82169
# 120 mof_unit_82169
# mof_unit_82271
# 121 mof_unit_82271
# mof_unit_82329
# 122 mof_unit_82329
# mof_unit_82348
# 123 mof_unit_82348
# mof_unit_82385
# 124 mof_unit_82385
# mof_unit_82425
# 125 mof_unit_82425
# mof_unit_82650
# 126 mof_unit_82650
# mof_unit_82679
# 127 mof_unit_82679
# mof_unit_82843
# 128 mof_unit_82843
# mof_unit_82874
# 129 mof_unit_82874
# mof_unit_82922
# 130 mof_unit_82922

# %%
import pandas as pd
pre_data=pd.DataFrame()
pre_data['MOFname']=dats[-1]
pre_data['volume [A^3]']=dats[0]
pre_data['weight [u]']=dats[1]
pre_data['surface_area [m^2/g]']=dats[2]
pre_data['void_fraction']=dats[3]
pre_data['void_volume [cm^3/g]']=dats[4]
pre_data['functional_groups_1']=dats[5]
pre_data['functional_groups_2']=dats[6]
pre_data['metal_linker']=dats[7]
pre_data['organic_linker1']=dats[8]
pre_data['organic_linker2']=dats[9]
pre_data['topology']=dats[10]
pre_data['CO2/N2_selectivity']=dats[11]
pre_data['heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]']=dats[12]
# pre_data['CO2_working_capacity [mL/g]']=dats[13]

# %%
pre_data
# Out:
#               MOFname  volume [A^3]  weight [u]  surface_area [m^2/g]  \
# 0      mof_unit_68614   1208.301332   797.70936                586.54
# 1      mof_unit_68615   4126.414623  3733.65779                852.49
# 2      mof_unit_68616   1602.148373   747.21048               3155.73
# 3      mof_unit_68617   2436.629312   995.80232               3521.09
# 4      mof_unit_68618   3123.418006  1337.53800               2678.46
# ...               ...           ...         ...                   ...
# 16995  mof_unit_85609  32660.944605  4723.68288               5720.14
# 16996  mof_unit_85610   5070.998617  1499.13262               4017.28
# 16997  mof_unit_85611   4669.804446  1322.04892               4288.76
# 16998  mof_unit_85612   4682.120862  1213.51148               4331.86
# 16999  mof_unit_85613  25702.628698  4793.21712               5006.39
#
#        void_fraction  void_volume [cm^3/g]  functional_groups_1  \
# 0            0.11392                0.1039                    9
# 1            0.21367                0.1422                   11
# 2            0.33883                0.4375                   16
# 3            0.40464                0.5963                    1
# 4            0.38959                0.5479                    0
# ...              ...                   ...                  ...
# 16995        0.77614                3.2318                    5
# 16996        0.59192                1.2058                    8
# 16997        0.54950                1.1689                    8
# 16998        0.60643                1.4091                    5
# 16999        0.71730                2.3163                    1
#
#        functional_groups_2  metal_linker  organic_linker1  organic_linker2  \
# 0                       -1             2                5               26
# 1                       18             4                6               17
# 2                        5             3               11               17
# 3                       -1             2                1               28
# 4                       14             3                8               19
# ...                    ...           ...              ...              ...
# 16995                    0             3                3               14
# 16996                    1             3                1               11
# 16997                   16             2                7               23
# 16998                    4             3                7               25
# 16999                   -1             1                2               27
#
#        topology  CO2/N2_selectivity  \
# 0             5           36.639791
# 1             0           18.390691
# 2             5           13.062850
# 3             5            9.601198
# 4             5           12.974954
# ...         ...                 ...
# 16995         4            4.536626
# 16996         4            6.745508
# 16997         5            4.666206
# 16998         5            4.823305
# 16999         5            4.278184
#
#        heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]
# 0                                           7.005640
# 1                                           5.119399
# 2                                           5.045400
# 3                                           5.106238
# 4                                           5.287639
# ...                                              ...
# 16995                                       3.146698
# 16996                                       3.658871
# 16997                                       3.593052
# 16998                                       3.454497
# 16999                                       3.169874
#
# [17000 rows x 14 columns]

# %%
pre_data.to_csv('pre_data_test_v_2.csv',index=False)

# %%
pre_data.describe()
# Out:
#        volume [A^3]    weight [u]  surface_area [m^2/g]  void_fraction  \
# count  17000.000000  17000.000000          17000.000000   17000.000000
# mean    3962.093864   1697.241546           2154.545616       0.314153
# std     5301.685232   1347.831034           1212.484791       0.148626
# min      608.378482    439.281220             46.470000       0.036330
# 25%     1626.629301    901.255060           1255.760000       0.207998
# 50%     2405.517700   1252.333940           1951.140000       0.288565
# 75%     4097.183391   1945.745466           2837.680000       0.380902
# max    78968.779431  21347.653440           6955.780000       0.871740
#
#        void_volume [cm^3/g]  functional_groups_1  functional_groups_2  \
# count          17000.000000         17000.000000         17000.000000
# mean               0.475059             8.703882             6.110765
# std                0.510588             5.613821             6.480543
# min                0.018600             0.000000            -1.000000
# 25%                0.197300             4.000000            -1.000000
# 50%                0.327750             9.000000             5.000000
# 75%                0.528550            13.000000            12.000000
# max                6.166500            19.000000            19.000000
#
#        metal_linker  organic_linker1  organic_linker2      topology  \
# count  17000.000000     17000.000000     17000.000000  17000.000000
# mean       3.972000        12.117765        20.997941      4.564471
# std        3.058374        10.625954         9.902528      1.963029
# min        1.000000         1.000000         1.000000      0.000000
# 25%        2.000000         4.000000        15.000000      5.000000
# 50%        3.000000        11.000000        21.000000      5.000000
# 75%        4.000000        16.000000        26.000000      5.000000
# max       12.000000        58.000000        58.000000     10.000000
#
#        CO2/N2_selectivity  heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]
# count        17000.000000                                   17000.000000
# mean            21.005006                                       5.585362
# std             15.191294                                       1.127235
# min              2.115394                                       1.706677
# 25%             11.960368                                       5.105133
# 50%             17.329899                                       5.646532
# 75%             25.834523                                       6.250551
# max            171.183935                                      11.019082
